# %% [markdown]
# ## imports

# %%
import pandas as pd

# %%
df_librarie = pd.read_excel('data/excelfiles/Urheber und Reihen.xlsx', sheet_name='Recherche', header=0)

df_blatter = pd.read_feather('data/feather/df_neuheiten_blatter.feather')
df_buchhaus = pd.read_feather('data/feather/df_neuheiten_buchhaus.feather')

# %% [markdown]
# ## Data Wrangling Urheber und Reihen

# %%
df_librarie
# Out:
#                  1. Urheber                       Alle Reihen
# 0                       NaN                      Asterix ; 20
# 1                       NaN                               NaN
# 2         May, Werner Jakob                               NaN
# 3      Schwaar, Hans Ulrich                               NaN
# 4          Engel, Franziska                               NaN
# ...                     ...                               ...
# 13723                   NaN  Schweizer Illustrierte ; 16/2023
# 13724                   NaN        Schweizer Garten ; 05/2023
# 13725       Guzowska, Marta                               NaN
# 13726      Gilbert, Lindsay                               NaN
# 13727       Bradford, Chris                Die Soul-Reihe ; 1
#
# [13728 rows x 2 columns]

# %%
# add new column to df_libarie with the second element in alle reihen after the semicolon
df_librarie['Reihe'] = df_librarie['Alle Reihen'].str.split(';').str[1]
df_librarie['Auflage'] = df_librarie['Alle Reihen'].str.split(';').str[0]

df_librarie = df_librarie[['1. Urheber', 'Auflage', 'Reihe']]

# %%
df_librarie.tail(10)
# Out:
#              1. Urheber                                            Auflage  \
# 13718               NaN                                 Schweizer Familie
# 13719   Geisler, Dagmar                                                NaN
# 13720               NaN  GEOlino: Die Welt für junge Entdeckerinnen und...
# 13721               NaN                       MERIAN : Die Lust am Reisen
# 13722      Evans, Cathy                                                NaN
# 13723               NaN                            Schweizer Illustrierte
# 13724               NaN                                  Schweizer Garten
# 13725   Guzowska, Marta                                                NaN
# 13726  Gilbert, Lindsay                                                NaN
# 13727   Bradford, Chris                                    Die Soul-Reihe
#
#           Reihe
# 13718   16/2023
# 13719       NaN
# 13720   05/2023
# 13721   23/2023
# 13722       NaN
# 13723   16/2023
# 13724   05/2023
# 13725       NaN
# 13726       NaN
# 13727         1

# %% [markdown]
# ## Datawrangling all scraped df

# %%
df_buchhaus.head()
# Out:
#                                 Titel  Preis  \
# 0  Atlas - Die Geschichte von Pa Salt    nan
# 1                           Der Feind  24.90
# 2                         Elternabend  23.90
# 3                   Anuschka und Finn  20.00
# 4                          Troubadour  35.00
#
#                                                Autor  \
# 0  Riley, LucindaWhittaker, HarryHauser, SonjaÜbe...
# 1                                   Brand, Christine
# 2                                  Fitzek, Sebastian
# 3                                  Schawinski, Roger
# 4       Walker, MartinWindgassen, MichaelÜbersetzung
#
#                             Genre  \
# 0             belletristik romane
# 1              belletristik krimi
# 2             belletristik romane
# 3  fachbuecher geschichte schweiz
# 4              belletristik krimi
#
#                                                 Text          ISBN/GTIN  \
# 0                                                nan               None
# 1  Ein bizarre Mordserie an Männern sowie Schüsse...  978-3-7645-0771-8
# 2  Stell dir vor ...\n... du musst eine halbe Ewi...  978-3-426-28413-1
# 3  Roger Schawinski über einen Medienskandal, der...  978-3-033-09890-9
# 4  Bruno steckt mitten in den Vorbereitungen für ...  978-3-257-07237-2
#
#   Produktart Einbandart         Verlag                    Erscheinungsdatum  \
# 0       None       None           None                                 None
# 1       Buch  Paperback      Blanvalet                           26.04.2023
# 2       Buch  Paperback  Droemer/Knaur  26.04.2023Erstverkaufstag26.04.2023
# 3       Buch  Paperback     Radio 1 AG                           12.05.2023
# 4       Buch   Gebunden       Diogenes                           26.04.2023
#
#   Auflage    Reihe Seiten  Sprache  \
# 0    None     None   None     None
# 1   1. A.  n-Nr.05         Deutsch
# 2             None         Deutsch
# 3    None     None         Deutsch
# 4   1. A.  n-Nr.15         Deutsch
#
#                                                Masse Artikel-Nr.
# 0                                               None        None
# 1                                               None        None
# 2            Breite 135 mm, Höhe 210 mm, Dicke 25 mm        None
# 3  Breite 144 mm, Höhe 221 mm, Dicke 15 mmGewicht...    58408389
# 4                                               None        None

# %%
df_blatter.head()
# Out:
#                                        Titel      Preis  \
# 0                   Der Auftrag des Papstes   CHF 18.50
# 1                          Im Jahr der Flut   CHF 19.90
# 2  Kinderklinik Weißensee - Geteilte Träume   CHF 18.50
# 3                               Nebelstunde   CHF 22.50
# 4                              Mädchenfeuer   CHF 18.50
#
#                                                 Text  \
# 0  Zusammenfassung\n1274: Nach abenteuerlichen Ja...
# 1  Zusammenfassung\n1900. Aufbruch in eine neue Z...
# 2  Zusammenfassung\nDer langersehnte vierte Band ...
# 3  Zusammenfassung\nEine Insel im Dunst der Erinn...
# 4  Zusammenfassung\nEin Kinderskelett in einer Hö...
#
#                                           Untertitel  \
# 0                                 Historischer Roman
# 1  Vier Frauen und ein Jahrhundertbauwerk, das di...
# 2          Roman | Die Kinderklinik-Saga geht weiter
# 3  Kriminalroman - Die SPIEGEL-Bestseller-Serie g...
# 4                           Ein Kommissar-Bark-Krimi
#
#                                        Autor              Verlag  Sprache  \
# 0   Panella, Luigi / Ickler, Ingrid (Übers.)            Goldmann  Deutsch
# 1                            Johannson, Lena           Aufbau TB  Deutsch
# 2                              Blum, Antonia  Econ-Ullstein-List  Deutsch
# 3      Mo, Johanna / Brauns, Ulrike (Übers.)     Heyne Taschenb.  Deutsch
# 4  Jansson, Anna / Dahmann, Susanne (Übers.)           Blanvalet  Deutsch
#
#   Einband Erscheinungsjahr  Seiten Artikelnummer               ISBN  \
# 0    (Kt)             2024  400 S.      42940145  978-3-442-49321-0
# 1    (Kt)             2024  512 S.      39065098  978-3-7466-3947-5
# 2    (Kt)             2024  512 S.      39191679  978-3-548-06796-4
# 3    (Kt)             2024  496 S.      44093859  978-3-453-42857-7
# 4    (Kt)             2024  420 S.      44175982  978-3-7341-1267-6
#
#                 Auflage                        Reihe Reihenbandnummer
# 0  Deutsche Erstausgabe  Die Chronik des Inquisitors               03
# 1                                   Nord-Ostsee-Saga               03
# 2                  None             Die Kinderärztin               04
# 3  Deutsche Erstausgabe      Die Hanna Duncker-Serie               04
# 4  Deutsche Erstausgabe              Kristoffer Bark               04

# %%
df_blatter.rename(columns={'Erscheinungsjahr': 'Erscheinungsdatum', 'ISBN': 'ISBN/GTIN'}, inplace=True)

# %%
df_buchhaus.columns
# Out:
# Index(['Titel', 'Preis', 'Autor', 'Genre', 'Text', 'ISBN/GTIN', 'Produktart',
#        'Einbandart', 'Verlag', 'Erscheinungsdatum', 'Auflage', 'Reihe',
#        'Seiten', 'Sprache', 'Masse', 'Artikel-Nr.'],
#       dtype='object')

# %%
# merge df_blatter and df_buchhaus
df = pd.concat([df_blatter, df_buchhaus], ignore_index=True)

# %%
df.shape
# Out:
# (270, 20)

# %%
df.head()
# Out:
#                                        Titel      Preis  \
# 0                   Der Auftrag des Papstes   CHF 18.50
# 1                          Im Jahr der Flut   CHF 19.90
# 2  Kinderklinik Weißensee - Geteilte Träume   CHF 18.50
# 3                               Nebelstunde   CHF 22.50
# 4                              Mädchenfeuer   CHF 18.50
#
#                                                 Text  \
# 0  Zusammenfassung\n1274: Nach abenteuerlichen Ja...
# 1  Zusammenfassung\n1900. Aufbruch in eine neue Z...
# 2  Zusammenfassung\nDer langersehnte vierte Band ...
# 3  Zusammenfassung\nEine Insel im Dunst der Erinn...
# 4  Zusammenfassung\nEin Kinderskelett in einer Hö...
#
#                                           Untertitel  \
# 0                                 Historischer Roman
# 1  Vier Frauen und ein Jahrhundertbauwerk, das di...
# 2          Roman | Die Kinderklinik-Saga geht weiter
# 3  Kriminalroman - Die SPIEGEL-Bestseller-Serie g...
# 4                           Ein Kommissar-Bark-Krimi
#
#                                        Autor              Verlag  Sprache  \
# 0   Panella, Luigi / Ickler, Ingrid (Übers.)            Goldmann  Deutsch
# 1                            Johannson, Lena           Aufbau TB  Deutsch
# 2                              Blum, Antonia  Econ-Ullstein-List  Deutsch
# 3      Mo, Johanna / Brauns, Ulrike (Übers.)     Heyne Taschenb.  Deutsch
# 4  Jansson, Anna / Dahmann, Susanne (Übers.)           Blanvalet  Deutsch
#
#   Einband Erscheinungsdatum  Seiten Artikelnummer          ISBN/GTIN  \
# 0    (Kt)              2024  400 S.      42940145  978-3-442-49321-0
# 1    (Kt)              2024  512 S.      39065098  978-3-7466-3947-5
# 2    (Kt)              2024  512 S.      39191679  978-3-548-06796-4
# 3    (Kt)              2024  496 S.      44093859  978-3-453-42857-7
# 4    (Kt)              2024  420 S.      44175982  978-3-7341-1267-6
#
#                 Auflage                        Reihe Reihenbandnummer Genre  \
# 0  Deutsche Erstausgabe  Die Chronik des Inquisitors               03   NaN
# 1                                   Nord-Ostsee-Saga               03   NaN
# 2                  None             Die Kinderärztin               04   NaN
# 3  Deutsche Erstausgabe      Die Hanna Duncker-Serie               04   NaN
# 4  Deutsche Erstausgabe              Kristoffer Bark               04   NaN
#
#   Produktart Einbandart Masse Artikel-Nr.
# 0        NaN        NaN   NaN         NaN
# 1        NaN        NaN   NaN         NaN
# 2        NaN        NaN   NaN         NaN
# 3        NaN        NaN   NaN         NaN
# 4        NaN        NaN   NaN         NaN

# %% [markdown]
# ## Book analysis

# %%
# autors which have new books on the market and are in the librarie
interresting_books = df[df['Autor'].isin(df_librarie['1. Urheber'])]
interresting_books.head()
# Out:
#                                                Titel      Preis  \
# 1                                  Im Jahr der Flut   CHF 19.90
# 2          Kinderklinik Weißensee - Geteilte Träume   CHF 18.50
# 7   Ocean View Avenue - Wo deine Träume wahr werden   CHF 16.90
# 26                              Bleich wie der Mond   CHF 21.00
# 27                          Das Geheimnis der Söhne   CHF 24.90
#
#                                                  Text  \
# 1   Zusammenfassung\n1900. Aufbruch in eine neue Z...
# 2   Zusammenfassung\nDer langersehnte vierte Band ...
# 7   Zusammenfassung\nWillkommen in der Ocean View ...
# 26  Zusammenfassung\nIn der Nacht spazierte er noc...
# 27  Zusammenfassung\nDie toughe TV-Journalistin Mi...
#
#                                            Untertitel             Autor  \
# 1   Vier Frauen und ein Jahrhundertbauwerk, das di...   Johannson, Lena
# 2           Roman | Die Kinderklinik-Saga geht weiter     Blum, Antonia
# 7                                               Roman    Thompson, Ella
# 26                                    Der Capri-Krimi     Ventura, Luca
# 27                            Ein Fall für Milla Nova  Brand, Christine
#
#                 Verlag  Sprache Einband Erscheinungsdatum  Seiten  \
# 1            Aufbau TB  Deutsch    (Kt)              2024  512 S.
# 2   Econ-Ullstein-List  Deutsch    (Kt)              2024  512 S.
# 7      Heyne Taschenb.  Deutsch    (Kt)              2024  448 S.
# 26            Diogenes  Deutsch    (Kt)              2023  304 S.
# 27            Atlantis  Deutsch    (Kt)              2023  352 S.
#
#    Artikelnummer          ISBN/GTIN          Auflage                    Reihe  \
# 1       39065098  978-3-7466-3947-5                          Nord-Ostsee-Saga
# 2       39191679  978-3-548-06796-4             None         Die Kinderärztin
# 7       44176005  978-3-453-42771-6  Originalausgabe
# 26      42875401  978-3-257-30095-6            1. A.                     None
# 27      42907406  978-3-7152-5502-6            1. A.  Ein Fall für Milla Nova
#
#    Reihenbandnummer Genre Produktart Einbandart Masse Artikel-Nr.
# 1                03   NaN        NaN        NaN   NaN         NaN
# 2                04   NaN        NaN        NaN   NaN         NaN
# 7                01   NaN        NaN        NaN   NaN         NaN
# 26             None   NaN        NaN        NaN   NaN         NaN
# 27               01   NaN        NaN        NaN   NaN         NaN

# %%
# Reihen which have new books on the market and are in the librarie
df[df['Reihe'].isin(df_librarie['Reihe'])]
# Out:
#                                                Titel      Preis  \
# 6                              Dark Elite - Regrets   CHF 22.50
# 7   Ocean View Avenue - Wo deine Träume wahr werden   CHF 16.90
# 35                                           Wagner   CHF 23.90
#
#                                                  Text  \
# 6   Zusammenfassung\nWie weit würdest du gehen, um...
# 7   Zusammenfassung\nWillkommen in der Ocean View ...
# 35  Zusammenfassung\nTrotz höchster Sicherheitsvor...
#
#                                            Untertitel  \
# 6   Roman - Mit farbig gestaltetem Buchschnitt - n...
# 7                                               Roman
# 35                                           Thriller
#
#                                           Autor           Verlag  Sprache  \
# 6                               Hausburg, Julia  Heyne Taschenb.  Deutsch
# 7                                Thompson, Ella  Heyne Taschenb.  Deutsch
# 35  Skördeman, Gustaf / Alms, Thorsten (Übers.)  Lübbe Paperback  Deutsch
#
#    Einband Erscheinungsdatum  Seiten Artikelnummer          ISBN/GTIN  \
# 6     (Kt)              2024  400 S.      44175609  978-3-453-42861-4
# 7     (Kt)              2024  448 S.      44176005  978-3-453-42771-6
# 35    (Kt)              2023  512 S.      42888361  978-3-7857-2850-5
#
#             Auflage Reihe        Reihenbandnummer Genre Produktart Einbandart  \
# 6   Originalausgabe                            02   NaN        NaN        NaN
# 7   Originalausgabe                            01   NaN        NaN        NaN
# 35    1. Aufl. 2023        03\nSonstiges Ab 16 J.   NaN        NaN        NaN
#
#    Masse Artikel-Nr.
# 6    NaN         NaN
# 7    NaN         NaN
# 35   NaN         NaN

# %% [markdown]
# ## export

# %%
interresting_books.reset_index(drop=True, inplace=True)

interresting_books.to_excel('data/excelfiles/df_interresting_books.xlsx', index=False)
interresting_books.to_feather('data/feather/df_interresting_books.feather')

# %% [markdown]
# ## Ausblick

# %% [markdown]
# Weitere Informationen:
#
# * Buchtitel der bestehenden Bücher um doppelte bücher zu erkennen
